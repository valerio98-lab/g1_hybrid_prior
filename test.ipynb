# %%
import numpy as np 

a = np.loadtxt("data_raw/LAFAN1_Retargeting_Dataset/g1/dance1_subject1.csv", delimiter=",", max_rows=20, skiprows=1*20)
i = 0
for row in a:
    print(row[0])
    i+=0
    if i>10:
        break
# Out:
# -0.004826
# -0.004758
# -0.004679
# -0.0046
# -0.004539
# -0.004501
# -0.004485
# -0.004488
# -0.004508
# -0.004539
# -0.004574
# -0.004609
# -0.004641
# -0.00467
# -0.004696
# -0.004715
# -0.004729
# -0.004733
# -0.004727
# -0.004712

# %%
import torch 
w, x, y, z = 1.0, 0.0, 0.0, 0.0
b = torch.tensor([w,x,y,z], dtype=torch.float32)
b.unbind(-1)

n = None
c = n or "cpu"
c
# Out:
# 'cpu'

# %%
pipi = 5

print(f"{pipi=}")
# Out:
# pipi=5

# %%
import torch 

test = torch.randint(
    low=0, high=10, size=(3,2)
)
test2 = test.unsqueeze(dim=1)

a = test.unsqueeze(dim=1)
b = test2
torch.cat((a, b), dim=-1), a
# Out:
# (tensor([[[4, 2, 4, 2]],
#
#          [[4, 1, 4, 1]],
#
#          [[9, 9, 9, 9]]]),
#  tensor([[[4, 2]],
#
#          [[4, 1]],
#
#          [[9, 9]]]))

# %%
dataset = ["a", "b", "c", "d", "e"]
gabbibbo = dataset[2:] + dataset[0:2]
print(gabbibbo)
a = []

for g in dataset: 
    a.append(gabbibbo.index(g))
a
# Out:
# ['c', 'd', 'e', 'a', 'b']
# ['d' 'e' 'a' 'b' 'c']

# %%
d = torch.tensor([1,2,3]).unsqueeze(0)
d[:, [0,2]]

k = []
for i in range(10):
    k.append(torch.randint(0, 10, (29,)))
