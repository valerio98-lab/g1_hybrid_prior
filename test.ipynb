# %%
import numpy as np 

a = np.loadtxt("data_raw/LAFAN1_Retargeting_Dataset/g1/dance1_subject1.csv", delimiter=",")
a[0]
# Out:
# array([ 9.800000e-05, -1.610000e-04,  7.990870e-01,  4.109000e-03,
#         2.375000e-03,  2.164100e-02,  9.997550e-01, -4.409000e-03,
#         6.053200e-02,  1.664310e-01,  1.762760e-01, -9.747300e-02,
#        -2.396200e-02,  4.031300e-02, -1.194140e-01, -3.858170e-01,
#         2.066740e-01, -1.808230e-01,  3.982900e-02,  1.606100e-02,
#        -6.092000e-03,  1.142000e-03, -6.888500e-02,  1.474532e+00,
#        -1.724690e-01,  1.220329e+00,  2.815510e-01,  2.297780e-01,
#         1.961300e-01,  6.326500e-02, -1.454644e+00,  1.670000e-04,
#         1.374207e+00, -1.747600e-02,  6.943200e-02, -1.628740e-01])
